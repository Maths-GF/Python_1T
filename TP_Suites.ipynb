# %% [markdown]
# # Les suites et les listes

# %% [markdown]
# ## I Calculer un terme d'une suite via une boucle `for`

# %% [markdown]
# Soit la suite définie par récurrence : $\left\{\begin{array}{l}u_0 = 2\ 000\\ u_{n+1} = (u_n + 650) \times 1,0015\end{array}\right.$
#
# Elle représente la somme sur un livret d’épargne après $n$ mois.

# %%
# Voici un exemple de code :
u = 2000
u = (u + 650)*1.0015
print(u)
# Out:
# 2653.9750000000004

# %% [markdown]
# __Question__ : Quel rang de la suite a été calculé ?

# %% [markdown]
# Réponse :

# %% [markdown]
# Pour calculer $u_{12}$, il faudrait répéter 12 fois le calcul :

# %%
u = 2000
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
u = (u + 650)*1.0015
print(u)
# Out:
# 9912.768337798698

# %% [markdown]
# Pour répéter un code plusieurs fois, on utilise des boucles. Nous verrons deux types de boucles : les boucles `for` (Pour en français) et `while` (Tant que en français).

# %% [markdown]
# Une boucle `for` permet de répéter des instructions un nombre fixe de fois.

# %%
# Répétons 12 fois le calcul
u = 2000
for i in range(12):
    u = (u + 650)*1.0015
print(u)
# Out:
# 9912.768337798698

# %% [markdown]
# __Question__ : En copiant et modifiant le code ci-dessus, donnez $u_{2021}$.

# %%
# Votre code ci-dessous :
# Out:
# 8582707.378854217

# %% [markdown]
# Réponse :

# %% [markdown]
# ## II Calculer un terme d'une suite via une boucle `while`

# %% [markdown]
# Une boucle `while` répète des instructions tant qu'une condition reste vraie.

# %%
n = 0
u = 2000
while n < 12:
    u = (u + 650) * 1.0015
    n = n+1
print("Le terme de rang", n, "vaut", u)
# Out:
# Le terme de rang 12 vaut 9912.768337798698

# %% [markdown]
# La variable `n` contient le rang actuel de la suite et `u` sa valeur. On répète le calcul tant que le rang est plus petit que 12.
#
# Les instructions répétées sont le calcul du terme suivant mais aussi l'augmentation du rang de 1.

# %% [markdown]
# __Question__ : En copiant et modifiant le code ci-dessus, retrouvez la valeur de $𝑢_{2021}$.

# %%
# Votre code ci-dessous :

# %% [markdown]
# ## III Les listes

# %% [markdown]
# En Python, une liste (`list`) est une succession d'objets.

# %% [markdown]
# ### III a Créer une liste

# %%
# On peut créer une liste en énumérant tous ses éléments :
l = [0, 1, 2, 3]
l
# Out:
# [0, 1, 2, 3]

# %%
# On peut créer une liste en ajoutant des éléments au fur et à mesure.
# On crée d'abord une liste vide puis on ajoute les éléments dans l'ordre.
l = []
l.append(0)
l.append(1)
l.append(2)
l.append(3)
l
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# ### III b Accéder aux éléments d'une liste

# %% [markdown]
# Comme les termes d'une suite, les éléments d'une liste sont numérotés à partir de 0.

# %%
# Créons une liste l :
l = [8, 5, 3, -7]
# Affichons l'élément de rang 0 (on dit d'indice 0)
print(l[0])
# Puis tous les indices suivant :
print(l[1])
print(l[2])
print(l[3])
# Out:
# 8
# 5
# 3
# -7

# %% [markdown]
# On peut également afficher la longueur d'une liste :

# %%
l = [8, 5, 3, -7]
len(l)
# Out:
# 4

# %% [markdown]
# ### III c Créons une liste contenant les éléments d'une suite

# %%
# On crée une suite avec le terme initial
l = [2000]
u = 2000
while len(l) < 13 :
    u = (u+650)*1.0015
    l.append(u)
l
# Out:
# [2000,
#  2653.9750000000004,
#  3308.9309625000005,
#  3964.8693589437507,
#  4621.791662982167,
#  5279.699350476641,
#  5938.593899502356,
#  6598.47679035161,
#  7259.349505537139,
#  7921.213529795445,
#  8584.070350090138,
#  9247.921455615275,
#  9912.768337798698]

# %%
# On crée une suite avec le terme initial
l = [2000]
n = 0
while n < 12 :
    l.append( (l[n]+650)*1.0015 )
    # on ajoute à la liste le terme suivant
    # n'oubliez pas que l[n] est l'élément d'indice n de la liste
    n = n+1
l
# Out:
# [2000,
#  2653.9750000000004,
#  3308.9309625000005,
#  3964.8693589437507,
#  4621.791662982167,
#  5279.699350476641,
#  5938.593899502356,
#  6598.47679035161,
#  7259.349505537139,
#  7921.213529795445,
#  8584.070350090138,
#  9247.921455615275,
#  9912.768337798698]

# %%
l = [2000]
for i in range(12) :
    l.append( (l[i]+650)*1.0015 )
    # on ajoute à la liste le terme suivant
l
# Out:
# [2000,
#  2653.9750000000004,
#  3308.9309625000005,
#  3964.8693589437507,
#  4621.791662982167,
#  5279.699350476641,
#  5938.593899502356,
#  6598.47679035161,
#  7259.349505537139,
#  7921.213529795445,
#  8584.070350090138,
#  9247.921455615275,
#  9912.768337798698]
